# %%
import numpy as np
import pandas as pd
temp = ['上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '酒类液体易碎品', '3-4天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '整车，回程车', '48小时', '市场价：                        7800.00                        元/公斤                        会员价：7722.00元/公斤', '市场价：                        7800.00                        元/立方会员价：7722.00元/立方', '6800.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '2天', '市场价：                        2.14                        元/公斤                        会员价：1.90元/公斤', '市场价：                        535.00                        元/立方会员价：476.00元/立方', '35.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '2天', '市场价：                        2.24                        元/公斤                        会员价：1.99元/公斤', '市场价：                        560.00                        元/立方会员价：498.00元/立方', '35.00元', '', '上海                             到                            北京', '德邦', '精准汽运（长）', '3-4天', '市场价：                        1.97                        元/公斤                        会员价：1.67元/公斤', '市场价：                        414.00                        元/立方会员价：352.00元/立方', '30.00元', '', '上海                             到                            北京', '德邦', '精准汽运（长）', '3-4天', '市场价：                        2.07                        元/公斤                        会员价：1.76元/公斤', '市场价：                        435.00                        元/立方会员价：370.00元/立方', '50.00元', '', '上海                             到                            北京', '德邦', '精准卡航', '二日13:00', '市场价：                        2.39                        元/公斤                        会员价：2.03元/公斤', '市场价：                        502.00                        元/立方会员价：427.00元/立方', '40.00元', '', '上海                             到                            北京', '德邦', '精准卡航', '二日13:00', '市场价：                        2.49                        元/公斤                        会员价：2.12元/公斤', '市场价：                        523.00                        元/立方会员价：445.00元/立方', '60.00元', '', '上海                             到                            北京', '天地华宇', '经济快运', '3-4天', '市场价：                        1.70                        元/公斤                        会员价：1.53元/公斤', '市场价：                        374.00                        元/立方会员价：337.00元/立方', '30.00元', '', '上海                             到                            北京', '天地华宇', '经济快运', '3-4天', '市场价：                        1.80                        元/公斤                        会员价：1.62元/公斤', '市场价：                        396.00                        元/立方会员价：356.00元/立方', '50.00元', '', '上海                             到                            北京', '天地华宇', '定日达', '2天', '市场价：                        2.05                        元/公斤                        会员价：1.85元/公斤', '市场价：                        451.00                        元/立方会员价：406.00元/立方', '35.00元', '', '上海                             到                            北京', '天地华宇', '定日达', '2天', '市场价：                        2.15                        元/公斤                        会员价：1.94元/公斤', '市场价：                        473.00                        元/立方会员价：426.00元/立方', '55.00元', '', '上海                             到                            北京', '大达物流', '大达标准件', '5天', '市场价：                        1.26                        元/公斤                        会员价：1.11元/公斤', '市场价：                        265.00                        元/立方会员价：233.00元/立方', '100.00元', '', '上海                             到                            北京', '中铁物流', '汽运专线', '2-3天', '市场价：                        1.43                        元/公斤                        会员价：1.43元/公斤', '市场价：                        328.00                        元/立方会员价：328.00元/立方', '55.00元', '', '上海                             到                            北京', '远成快运', '零担≥30KG', '2-3天', '市场价：                        1.55                        元/公斤                        会员价：1.36元/公斤', '市场价：                        310.00                        元/立方会员价：273.00元/立方', '50.00元', '', '上海                             到                            北京', '大达物流', '大达优选', '4天', '市场价：                        1.44                        元/公斤                        会员价：1.27元/公斤', '市场价：                        302.00                        元/立方会员价：266.00元/立方', '110.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.43                        元/公斤                        会员价：1.43元/公斤', '市场价：                        286.00                        元/立方会员价：286.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '惠心件<70', '3天', '市场价：                        1.57                        元/公斤                        会员价：1.57元/公斤', '市场价：                        315.00                        元/立方会员价：315.00元/立方', '50.00元', '', '上海                             到                            北京', '新邦物流', '新邦专线', '第3~4天', '市场价：                        1.50                        元/公斤                        会员价：1.35元/公斤', '市场价：                        350.00                        元/立方会员价：315.00元/立方', '50.00元', '', '上海                             到                            北京', '新邦物流', '新邦快线', '第2天13:00', '市场价：                        1.85                        元/公斤                        会员价：1.67元/公斤', '市场价：                        430.00                        元/立方会员价：387.00元/立方', '60.00元', '', '上海                             到                            北京', '申胜物流', '干线专运', '2天', '市场价：                        0.48                        元/公斤                        会员价：0.48元/公斤', '市场价：                        145.00                        元/立方会员价：145.00元/立方', '400.00元', '', '上海                             到                            北京', '中通快运', '标准快运', '2-3天', '市场价：                        1.95                        元/公斤                        会员价：1.95元/公斤', '市场价：                        390.00                        元/立方会员价：390.00元/立方', '50.00元', '', '上海                             到                            北京', '盛辉物流', '汽运专线', '3-4天', '市场价：                        0.95                        元/公斤                        会员价：0.91元/公斤', '市场价：                        189.00                        元/立方会员价：180.00元/立方', '30.00元', '', '上海                             到                            北京', '卡行天下', '卡行小票直通车', '3天', '市场价：                        1.88                        元/公斤                        会员价：1.50元/公斤', '市场价：                        375.00                        元/立方会员价：300.00元/立方', '200.00元', '', '上海                             到                            北京', '兴铁物流', '直达专线', '2-3天', '市场价：                        0.90                        元/公斤                        会员价：0.77元/公斤', '市场价：                        225.00                        元/立方会员价：191.00元/立方', '300.00元', '', '上海                             到                            北京', '聚创物流', '≥2000kg或8m³', '2-3天', '市场价：                        0.50                        元/公斤                        会员价：0.50元/公斤', '市场价：                        160.00                        元/立方会员价：160.00元/立方', '300.00元', '', '上海                             到                            北京', '百世物流', '钜惠快件>1T', '3天', '市场价：                        1.30                        元/公斤                        会员价：1.30元/公斤', '市场价：                        260.00                        元/立方会员价：260.00元/立方', '1300.00元', '', '上海                             到                            北京', '骐胜物流', '整车12.5米车', '1天内', '市场价：                        0.27                        元/公斤                        会员价：0.26元/公斤', '市场价：                        118.00                        元/立方会员价：112.00元/立方', '8500.00元', '', '上海                             到                            北京', '骐胜物流', '整车17.5米车', '1天内', '市场价：                        0.41                        元/公斤                        会员价：0.39元/公斤', '市场价：                        118.00                        元/立方会员价：112.00元/立方', '12900.00元', '', '上海                             到                            北京', '铭龙物流', '精品直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：150.00元/立方', '460.00元', '', '上海                             到                            北京', '传邦物流', '≥800KG或4立方', '2天', '市场价：                        0.50                        元/公斤                        会员价：0.50元/公斤', '市场价：                        144.00                        元/立方会员价：143.00元/立方', '400.00元', '', '上海                             到                            北京', '骐胜物流', '零担汽运专线', '1-2天', '市场价：                        0.66                        元/公斤                        会员价：0.63元/公斤', '市场价：                        165.00                        元/立方会员价：157.00元/立方', '150.00元', '', '上海                             到                            北京', '骐胜物流', '整车9.6米车', '1天内', '市场价：                        0.66                        元/公斤                        会员价：0.63元/公斤', '市场价：                        147.00                        元/立方会员价：140.00元/立方', '6600.00元', '', '上海                             到                            北京', '骐胜物流', '整车6.2米车', '1天内', '市场价：                        0.71                        元/公斤                        会员价：0.67元/公斤', '市场价：                        189.00                        元/立方会员价：180.00元/立方', '5100.00元', '', '上海                             到                            北京', '速雁速运', '精准卡航速运', '2-3天', '市场价：                        0.95                        元/公斤                        会员价：0.95元/公斤', '市场价：                        240.00                        元/立方会员价：240.00元/立方', '500.00元', '', '上海                             到                            北京', '卡行天下', '卡行大票直通车', '3天', '市场价：                        1.63                        元/公斤                        会员价：1.30元/公斤', '市场价：                        350.00                        元/立方会员价：280.00元/立方', '650.00元', '', '上海                             到                            北京', '中骅物流', 'e诺特惠长', '3-4天', '市场价：                        1.40                        元/公斤                        会员价：1.40元/公斤', '市场价：                        294.00                        元/立方会员价：294.00元/立方', '30.00元', '', '上海                             到                            北京', '安能物流', '标准快运>70kg', '3-4天', '市场价：                        2.06                        元/公斤                        会员价：1.81元/公斤', '市场价：                        412.00                        元/立方会员价：363.00元/立方', '60.00元', '', '上海                             到                            北京', '安能物流', '定时达', '2天', '市场价：                        2.16                        元/公斤                        会员价：1.90元/公斤', '市场价：                        432.00                        元/立方会员价：380.00元/立方', '50.00元', '', '上海                             到                            北京', '安能物流', 'MiNi小包≤70kg', '2天', '市场价：                        2.16                        元/公斤                        会员价：1.90元/公斤', '市场价：                        432.00                        元/立方会员价：380.00元/立方', '40.00元', '', '上海                             到                            北京', '远成快运', '30公斤以下', '2-3天', '市场价：                        3.00                        元/公斤                        会员价：2.64元/公斤', '市场价：                        500.00                        元/立方会员价：440.00元/立方', '32.00元', '', '上海                             到                            北京', '穗佳物流', '直达专线', '8小时', '市场价：                        8.60                        元/公斤                        会员价：7.31元/公斤', '市场价：                        1433.00                        元/立方会员价：1218.00元/立方', '108.00元', '', '上海                             到                            北京', '穗佳物流', '空运快线', '天', '市场价：                        8.60                        元/公斤                        会员价：7.31元/公斤', '市场价：                        1433.00                        元/立方会员价：1218.00元/立方', '108.00元', '', '上海                             到                            北京', '穗佳物流', '空运普通', '天', '市场价：                        8.60                        元/公斤                        会员价：7.31元/公斤', '市场价：                        1433.00                        元/立方会员价：1218.00元/立方', '108.00元', '', '上海                             到                            北京', '上海吉速速运有限公司', '空运', '40小时', '市场价：                        11.50                        元/公斤                        会员价：11.50元/公斤', '市场价：                        1955.00                        元/立方会员价：1955.00元/立方', '180.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '快运直达专线', '2-3天', '市场价：                        0.45                        元/公斤                        会员价：0.45元/公斤', '市场价：                        150.00                        元/立方会员价：149.00元/立方', '300.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '木箱货重泡货', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '酒类液体易碎品', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '昊昕物流', '酒类液体易碎品', '2-3天', '市场价：                        0.80                        元/公斤                        会员价：0.79元/公斤', '市场价：                        200.00                        元/立方会员价：198.00元/立方', '150.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '3天', '市场价：                        2.15                        元/公斤                        会员价：1.91元/公斤', '市场价：                        538.00                        元/立方会员价：479.00元/立方', '35.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '3天', '市场价：                        2.18                        元/公斤                        会员价：1.94元/公斤', '市场价：                        544.00                        元/立方会员价：484.00元/立方', '35.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '3天', '市场价：                        2.18                        元/公斤                        会员价：1.94元/公斤', '市场价：                        544.00                        元/立方会员价：484.00元/立方', '35.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '3天', '市场价：                        2.19                        元/公斤                        会员价：1.95元/公斤', '市场价：                        546.00                        元/立方会员价：486.00元/立方', '35.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '3天', '市场价：                        2.22                        元/公斤                        会员价：1.98元/公斤', '市场价：                        555.00                        元/立方会员价：494.00元/立方', '35.00元', '', '上海                             到                            北京', '佳吉快运', '汽运', '2天', '市场价：                        2.35                        元/公斤                        会员价：2.09元/公斤', '市场价：                        586.00                        元/立方会员价：522.00元/立方', '35.00元', '', '上海                             到                            北京', '德邦', '精准汽运（长）', '--天', '市场价：                        2.52                        元/公斤                        会员价：2.14元/公斤', '市场价：                        529.00                        元/立方会员价：450.00元/立方', '55.00元', '', '上海                             到                            北京', '德邦', '精准卡航', '--天', '市场价：                        2.93                        元/公斤                        会员价：2.49元/公斤', '市场价：                        615.00                        元/立方会员价：523.00元/立方', '65.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.44                        元/公斤                        会员价：1.44元/公斤', '市场价：                        288.00                        元/立方会员价：288.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.45                        元/公斤                        会员价：1.45元/公斤', '市场价：                        290.00                        元/立方会员价：290.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.47                        元/公斤                        会员价：1.47元/公斤', '市场价：                        295.00                        元/立方会员价：295.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.49                        元/公斤                        会员价：1.49元/公斤', '市场价：                        297.00                        元/立方会员价：297.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.50                        元/公斤                        会员价：1.50元/公斤', '市场价：                        299.00                        元/立方会员价：299.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.50                        元/公斤                        会员价：1.50元/公斤', '市场价：                        299.00                        元/立方会员价：299.00元/立方', '105.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.51                        元/公斤                        会员价：1.51元/公斤', '市场价：                        301.00                        元/立方会员价：301.00元/立方', '110.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.51                        元/公斤                        会员价：1.51元/公斤', '市场价：                        301.00                        元/立方会员价：301.00元/立方', '110.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.52                        元/公斤                        会员价：1.52元/公斤', '市场价：                        304.00                        元/立方会员价：304.00元/立方', '110.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.53                        元/公斤                        会员价：1.53元/公斤', '市场价：                        306.00                        元/立方会员价：306.00元/立方', '110.00元', '', '上海                             到                            北京', '百世物流', '标准快件70-1T', '3天', '市场价：                        1.54                        元/公斤                        会员价：1.54元/公斤', '市场价：                        308.00                        元/立方会员价：308.00元/立方', '110.00元', '', '上海                             到                            北京', '百世物流', '惠心件<70', '3天', '市场价：                        1.59                        元/公斤                        会员价：1.59元/公斤', '市场价：                        317.00                        元/立方会员价：317.00元/立方', '50.00元', '', '上海                             到                            北京', '百世物流', '惠心件<70', '3天', '市场价：                        1.60                        元/公斤                        会员价：1.60元/公斤', '市场价：                        319.00                        元/立方会员价：319.00元/立方', '50.00元', '', '上海                             到                            北京', '百世物流', '惠心件<70', '3天', '市场价：                        1.62                        元/公斤                        会员价：1.62元/公斤', '市场价：                        324.00                        元/立方会员价：324.00元/立方', '50.00元', '', '上海                             到                            北京', '百世物流', '惠心件<70', '3天', '市场价：                        1.63                        元/公斤                        会员价：1.63元/公斤', '市场价：                        327.00                        元/立方会员价：327.00元/立方', '50.00元', '']
col_names = [
    'route', 'company', 'brand', 'limitation', 'price_w', 'price_l', 'min', 'x'
]
temp_arr = np.reshape(temp, (100, 8))
temp_df = pd.DataFrame(data = temp_arr, columns = col_names)
temp_df.head(20)
temp_df.iloc[0,0].replace(' ', '')
# Out:
# '上海到北京'

# %%
url = 'http://56.1688.com/routes/shanghai.htm'  # 阿里巴巴物流上海线路
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0'}  # 构造头部
# cookie = {}
# pxs = {}  # TODO 代理池
r = requests.get(url, headers=headers)
soup = BeautifulSoup(r.text, 'html.parser')
sh2other = []  # 上海到其他城市转接列表
for x in soup.find_all(href=re.compile('.htm'), title=re.compile('上海')):
    sh2other.append(x['href'])

sh2other = sh2other[1:]  # 删除无用链接
sh2other
# Out:
# ['//56.1688.com/routes/shanghai-beijing.htm',
#  '//56.1688.com/routes/shanghai-chongqing.htm',
#  '//56.1688.com/routes/shanghai-chaozhou.htm',
#  '//56.1688.com/routes/shanghai-dongguan441900.htm',
#  '//56.1688.com/routes/shanghai-foshan.htm',
#  '//56.1688.com/routes/shanghai-guangzhou.htm',
#  '//56.1688.com/routes/shanghai-heyuan.htm',
#  '//56.1688.com/routes/shanghai-huizhou441300.htm',
#  '//56.1688.com/routes/shanghai-jiangmen.htm',
#  '//56.1688.com/routes/shanghai-jieyang.htm',
#  '//56.1688.com/routes/shanghai-maoming.htm',
#  '//56.1688.com/routes/shanghai-meizhou.htm',
#  '//56.1688.com/routes/shanghai-qingyuan441800.htm',
#  '//56.1688.com/routes/shanghai-shantou.htm',
#  '//56.1688.com/routes/shanghai-shanwei.htm',
#  '//56.1688.com/routes/shanghai-shaoguan.htm',
#  '//56.1688.com/routes/shanghai-shenzhen.htm',
#  '//56.1688.com/routes/shanghai-yangjiang.htm',
#  '//56.1688.com/routes/shanghai-yunfu.htm',
#  '//56.1688.com/routes/shanghai-zhanjiang.htm',
# ...

# %%
def pprint(*d):
    print(d, '\n')
pprint(sh2other)
len(sh2other)
# Out:
# (['//56.1688.com/routes/shanghai-beijing.htm', '//56.1688.com/routes/shanghai-chongqing.htm', '//56.1688.com/routes/shanghai-chaozhou.htm', '//56.1688.com/routes/shanghai-dongguan441900.htm', '//56.1688.com/routes/shanghai-foshan.htm', '//56.1688.com/routes/shanghai-guangzhou.htm', '//56.1688.com/routes/shanghai-heyuan.htm', '//56.1688.com/routes/shanghai-huizhou441300.htm', '//56.1688.com/routes/shanghai-jiangmen.htm', '//56.1688.com/routes/shanghai-jieyang.htm', '//56.1688.com/routes/shanghai-maoming.htm', '//56.1688.com/routes/shanghai-meizhou.htm', '//56.1688.com/routes/shanghai-qingyuan441800.htm', '//56.1688.com/routes/shanghai-shantou.htm', '//56.1688.com/routes/shanghai-shanwei.htm', '//56.1688.com/routes/shanghai-shaoguan.htm', '//56.1688.com/routes/shanghai-shenzhen.htm', '//56.1688.com/routes/shanghai-yangjiang.htm', '//56.1688.com/routes/shanghai-yunfu.htm', '//56.1688.com/routes/shanghai-zhanjiang.htm', '//56.1688.com/routes/shanghai-zhaoqing.htm', '//56.1688.com/routes/
# ...

# %%
import os
import re
import time
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0'}
def crawler(url):
    temp = []
    col_names = [
        'route', 'company', 'brand', 'limitation', 'price_w', 'price_l', 'min',
        'x'
    ]
    # 线路 	物流公司 	服务品牌 	参考时效 	单价（重货） 	单价（轻货） 	最低一票 abnormal
    test = requests.get(url, headers=headers)
    test_soup = BeautifulSoup(test.text, 'html.parser')
    new = test_soup.find(
        'body', class_='layout').find(
            'div', class_='section').find(
                'div', class_='recoLine').find('table').find('tbody')

    for x in new.find_all('td'):
        if re.search('简介', x.text):
            continue
        temp.append(x.text.strip().replace('\r\n', ''))

    a = np.reshape(temp, (int(len(temp) / 8), 8))
    df = pd.DataFrame(data=a, columns=col_names)
    print(df, df.empty)
    
crawler('http://56.1688.com/routes/shanghai-zhongshaqundaodedaojiaojiqihaiyu999469039.htm')
# Out:
# Empty DataFrame
# Columns: [route, company, brand, limitation, price_w, price_l, min, x]
# Index: [] True

# %%
df_empty = pd.DataFrame({'A' : []})
if not df_empty.empty():
    print(2)
else:
    print(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-31877e436540> in <module>()
#       1 df_empty = pd.DataFrame({'A' : []})
# ----> 2 if not df_empty.empty():
#       3     print(2)
#       4 else:
#       5     print(1)
#
# TypeError: 'bool' object is not callable

# %%
import tushare as ts
df = ts.realtime_boxoffice()
print(df)
# Out:
#    BoxOffice Irank MovieName boxPer movieDay sumBoxOffice                 time
# 0   11130.80     1        黑豹  44.62        3     42321.81  2018-03-11 23:21:00
# 1    4948.97     2      红海行动  19.84       24    333959.13  2018-03-11 23:21:00
# 2    2106.53     3    唐人街探案2   8.44       24    329660.08  2018-03-11 23:21:00
# 3    1837.51     4  小萝莉的猴神大叔   7.37       10     16528.67  2018-03-11 23:21:00
# 4    1303.06     5   厉害了，我的国   5.22       10     22708.82  2018-03-11 23:21:00
# 5    1144.78     6       比得兔   4.59       10     12611.75  2018-03-11 23:21:00
# 6     739.59     7      妈妈咪鸭   2.96        3      2985.65  2018-03-11 23:21:00
# 7     506.58     8     三块广告牌   2.03       10      4400.55  2018-03-11 23:21:00
# 8     366.81     9      恋爱回旋   1.47        3      1187.18  2018-03-11 23:21:00
# 9     361.37    10      捉妖记2   1.45       24    222174.52  2018-03-11 23:21:00
# 10    500.49    11        其它   1.00        0         0.00  2018-03-11 23:21:00
